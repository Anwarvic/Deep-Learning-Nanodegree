# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN on augmented images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
from tensorflow.keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from tensorflow.keras.utils import to_categorical

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
y_valid = to_categorical(y_valid, num_classes)

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Create and Configure Augmented Image Generator

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen_train.fit(x_train)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 6. Visualize Original and Augmented Images

# %%
import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;

# %% [markdown]
# ### 7. Define the Model Architecture
#
# ![CNN architecture](https://appliedmachinelearning.files.wordpress.com/2018/03/cnn.png?w=616)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers


weight_decay = 1e-4 #change weight decay from here
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
 
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
 
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_v1 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_v1_1 (Ba (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_v1_2 (Ba (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_v1_3 (Ba (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_v1_4 (Ba (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_v1_5 (Ba (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                20490
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# ### 8. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 9. Train the Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint   

batch_size = 32
epochs = 100

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs, verbose=2, callbacks=[checkpointer],
                    validation_data=(x_valid, y_valid),
                    validation_steps=x_valid.shape[0] // batch_size)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 5000/5000 [==============================] - 1s 179us/sample - loss: 1.3405 - acc: 0.5764
#
# Epoch 00001: val_loss improved from inf to 1.34010, saving model to aug_model.weights.best.hdf5
#  - 28s - loss: 1.9284 - acc: 0.4205 - val_loss: 1.3401 - val_acc: 0.5764
# Epoch 2/100
# 5000/5000 [==============================] - 1s 161us/sample - loss: 1.0338 - acc: 0.6816
#
# Epoch 00002: val_loss improved from 1.34010 to 1.03504, saving model to aug_model.weights.best.hdf5
#  - 25s - loss: 1.2761 - acc: 0.5914 - val_loss: 1.0350 - val_acc: 0.6816
# Epoch 3/100
# 5000/5000 [==============================] - 1s 153us/sample - loss: 1.0287 - acc: 0.6968
#
# Epoch 00003: val_loss improved from 1.03504 to 1.02833, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 1.0748 - acc: 0.6600 - val_loss: 1.0283 - val_acc: 0.6968
# Epoch 4/100
# 5000/5000 [==============================] - 1s 152us/sample - loss: 0.9947 - acc: 0.7038
#
# Epoch 00004: val_loss improved from 1.02833 to 0.99446, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.9754 - acc: 0.7001 - val_loss: 0.9945 - val_acc: 0.7038
# Epoch 5/100
# 5000/5000 [==============================] - 1s 152us/sample - loss: 0.8419 - acc: 0.7614
#
# Epoch 00005: val_loss improved from 0.99446 to 0.84166, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.9073 - acc: 0.7254 - val_loss: 0.8417 - val_acc: 0.7614
# Epoch 6/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.8271 - acc: 0.7654
#
# Epoch 00006: val_loss improved from 0.84166 to 0.82623, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.8729 - acc: 0.7416 - val_loss: 0.8262 - val_acc: 0.7654
# Epoch 7/100
# 5000/5000 [==============================] - 1s 155us/sample - loss: 0.7565 - acc: 0.7832
#
# Epoch 00007: val_loss improved from 0.82623 to 0.75575, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.8456 - acc: 0.7545 - val_loss: 0.7558 - val_acc: 0.7832
# Epoch 8/100
# 5000/5000 [==============================] - 1s 149us/sample - loss: 0.7030 - acc: 0.8172
#
# Epoch 00008: val_loss improved from 0.75575 to 0.70231, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.8175 - acc: 0.7635 - val_loss: 0.7023 - val_acc: 0.8172
# Epoch 9/100
# 5000/5000 [==============================] - 1s 153us/sample - loss: 0.8288 - acc: 0.7768
#
# Epoch 00009: val_loss did not improve from 0.70231
#  - 24s - loss: 0.7932 - acc: 0.7758 - val_loss: 0.8288 - val_acc: 0.7768
# Epoch 10/100
# 5000/5000 [==============================] - 1s 150us/sample - loss: 0.8357 - acc: 0.7706
#
# Epoch 00010: val_loss did not improve from 0.70231
#  - 24s - loss: 0.7866 - acc: 0.7791 - val_loss: 0.8360 - val_acc: 0.7706
# Epoch 11/100
# 5000/5000 [==============================] - 1s 157us/sample - loss: 0.7606 - acc: 0.7994
#
# Epoch 00011: val_loss did not improve from 0.70231
#  - 24s - loss: 0.7641 - acc: 0.7886 - val_loss: 0.7597 - val_acc: 0.7994
# Epoch 12/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.6875 - acc: 0.8226
#
# Epoch 00012: val_loss improved from 0.70231 to 0.68719, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.7557 - acc: 0.7934 - val_loss: 0.6872 - val_acc: 0.8226
# Epoch 13/100
# 5000/5000 [==============================] - 1s 150us/sample - loss: 0.7422 - acc: 0.8100
#
# Epoch 00013: val_loss did not improve from 0.68719
#  - 24s - loss: 0.7487 - acc: 0.7982 - val_loss: 0.7424 - val_acc: 0.8100
# Epoch 14/100
# 5000/5000 [==============================] - 1s 153us/sample - loss: 0.7041 - acc: 0.8142
#
# Epoch 00014: val_loss did not improve from 0.68719
#  - 24s - loss: 0.7440 - acc: 0.7982 - val_loss: 0.7045 - val_acc: 0.8142
# Epoch 15/100
# 5000/5000 [==============================] - 1s 151us/sample - loss: 0.6742 - acc: 0.8296
#
# Epoch 00015: val_loss improved from 0.68719 to 0.67505, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.7391 - acc: 0.8013 - val_loss: 0.6750 - val_acc: 0.8296
# Epoch 16/100
# 5000/5000 [==============================] - 1s 150us/sample - loss: 0.7063 - acc: 0.8172
#
# Epoch 00016: val_loss did not improve from 0.67505
#  - 24s - loss: 0.7289 - acc: 0.8058 - val_loss: 0.7081 - val_acc: 0.8172
# Epoch 17/100
# 5000/5000 [==============================] - 1s 155us/sample - loss: 0.6995 - acc: 0.8248
#
# Epoch 00017: val_loss did not improve from 0.67505
#  - 24s - loss: 0.7260 - acc: 0.8077 - val_loss: 0.6988 - val_acc: 0.8248
# Epoch 18/100
# 5000/5000 [==============================] - 1s 153us/sample - loss: 0.6498 - acc: 0.8414
#
# Epoch 00018: val_loss improved from 0.67505 to 0.64930, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.7193 - acc: 0.8104 - val_loss: 0.6493 - val_acc: 0.8414
# Epoch 19/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.6535 - acc: 0.8366
#
# Epoch 00019: val_loss did not improve from 0.64930
#  - 24s - loss: 0.7164 - acc: 0.8107 - val_loss: 0.6529 - val_acc: 0.8366
# Epoch 20/100
# 5000/5000 [==============================] - 1s 153us/sample - loss: 0.7246 - acc: 0.8168
#
# Epoch 00020: val_loss did not improve from 0.64930
#  - 24s - loss: 0.7121 - acc: 0.8146 - val_loss: 0.7240 - val_acc: 0.8168
# Epoch 21/100
# 5000/5000 [==============================] - 1s 157us/sample - loss: 0.6784 - acc: 0.8280
#
# Epoch 00021: val_loss did not improve from 0.64930
#  - 24s - loss: 0.7046 - acc: 0.8167 - val_loss: 0.6787 - val_acc: 0.8280
# Epoch 22/100
# 5000/5000 [==============================] - 1s 153us/sample - loss: 0.6901 - acc: 0.8266
#
# Epoch 00022: val_loss did not improve from 0.64930
#  - 24s - loss: 0.7047 - acc: 0.8182 - val_loss: 0.6900 - val_acc: 0.8266
# Epoch 23/100
# 5000/5000 [==============================] - 1s 153us/sample - loss: 0.7506 - acc: 0.8096
#
# Epoch 00023: val_loss did not improve from 0.64930
#  - 24s - loss: 0.6981 - acc: 0.8187 - val_loss: 0.7506 - val_acc: 0.8096
# Epoch 24/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.6529 - acc: 0.8390
#
# Epoch 00024: val_loss did not improve from 0.64930
#  - 24s - loss: 0.7017 - acc: 0.8195 - val_loss: 0.6545 - val_acc: 0.8390
# Epoch 25/100
# 5000/5000 [==============================] - 1s 152us/sample - loss: 0.7628 - acc: 0.8020
#
# Epoch 00025: val_loss did not improve from 0.64930
#  - 24s - loss: 0.6967 - acc: 0.8213 - val_loss: 0.7647 - val_acc: 0.8020
# Epoch 26/100
# 5000/5000 [==============================] - 1s 157us/sample - loss: 0.7660 - acc: 0.8162
#
# Epoch 00026: val_loss did not improve from 0.64930
#  - 24s - loss: 0.6876 - acc: 0.8249 - val_loss: 0.7681 - val_acc: 0.8162
# Epoch 27/100
# 5000/5000 [==============================] - 1s 153us/sample - loss: 0.6329 - acc: 0.8424
#
# Epoch 00027: val_loss improved from 0.64930 to 0.63181, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.6899 - acc: 0.8228 - val_loss: 0.6318 - val_acc: 0.8424
# Epoch 28/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.6543 - acc: 0.8434
#
# Epoch 00028: val_loss did not improve from 0.63181
#  - 24s - loss: 0.6883 - acc: 0.8259 - val_loss: 0.6557 - val_acc: 0.8434
# Epoch 29/100
# 5000/5000 [==============================] - 1s 149us/sample - loss: 0.6622 - acc: 0.8386
#
# Epoch 00029: val_loss did not improve from 0.63181
#  - 24s - loss: 0.6869 - acc: 0.8268 - val_loss: 0.6615 - val_acc: 0.8386
# Epoch 30/100
# 5000/5000 [==============================] - 1s 151us/sample - loss: 0.7431 - acc: 0.8118
#
# Epoch 00030: val_loss did not improve from 0.63181
#  - 24s - loss: 0.6806 - acc: 0.8270 - val_loss: 0.7424 - val_acc: 0.8118
# Epoch 31/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.6322 - acc: 0.8454
#
# Epoch 00031: val_loss improved from 0.63181 to 0.63125, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.6798 - acc: 0.8288 - val_loss: 0.6312 - val_acc: 0.8454
# Epoch 32/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.6302 - acc: 0.8490
#
# Epoch 00032: val_loss improved from 0.63125 to 0.62908, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.6741 - acc: 0.8300 - val_loss: 0.6291 - val_acc: 0.8490
# Epoch 33/100
# 5000/5000 [==============================] - 1s 152us/sample - loss: 0.7583 - acc: 0.8144
#
# Epoch 00033: val_loss did not improve from 0.62908
#  - 24s - loss: 0.6847 - acc: 0.8258 - val_loss: 0.7577 - val_acc: 0.8144
# Epoch 34/100
# 5000/5000 [==============================] - 1s 153us/sample - loss: 0.6991 - acc: 0.8278
#
# Epoch 00034: val_loss did not improve from 0.62908
#  - 24s - loss: 0.6744 - acc: 0.8314 - val_loss: 0.6981 - val_acc: 0.8278
# Epoch 35/100
# 5000/5000 [==============================] - 1s 152us/sample - loss: 0.6480 - acc: 0.8444
#
# Epoch 00035: val_loss did not improve from 0.62908
#  - 24s - loss: 0.6791 - acc: 0.8281 - val_loss: 0.6481 - val_acc: 0.8444
# Epoch 36/100
# 5000/5000 [==============================] - 1s 151us/sample - loss: 0.6151 - acc: 0.8578
#
# Epoch 00036: val_loss improved from 0.62908 to 0.61632, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.6723 - acc: 0.8320 - val_loss: 0.6163 - val_acc: 0.8578
# Epoch 37/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.6892 - acc: 0.8354
#
# Epoch 00037: val_loss did not improve from 0.61632
#  - 24s - loss: 0.6708 - acc: 0.8330 - val_loss: 0.6884 - val_acc: 0.8354
# Epoch 38/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.6253 - acc: 0.8484
#
# Epoch 00038: val_loss did not improve from 0.61632
#  - 25s - loss: 0.6725 - acc: 0.8320 - val_loss: 0.6242 - val_acc: 0.8484
# Epoch 39/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.6830 - acc: 0.8336
#
# Epoch 00039: val_loss did not improve from 0.61632
#  - 24s - loss: 0.6682 - acc: 0.8340 - val_loss: 0.6821 - val_acc: 0.8336
# Epoch 40/100
# 5000/5000 [==============================] - 1s 155us/sample - loss: 0.6169 - acc: 0.8584
#
# Epoch 00040: val_loss improved from 0.61632 to 0.61596, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.6674 - acc: 0.8328 - val_loss: 0.6160 - val_acc: 0.8584
# Epoch 41/100
# 5000/5000 [==============================] - 1s 150us/sample - loss: 0.6155 - acc: 0.8602
#
# Epoch 00041: val_loss improved from 0.61596 to 0.61435, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.6629 - acc: 0.8367 - val_loss: 0.6143 - val_acc: 0.8602
# Epoch 42/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.6896 - acc: 0.8348
#
# Epoch 00042: val_loss did not improve from 0.61435
#  - 24s - loss: 0.6660 - acc: 0.8344 - val_loss: 0.6894 - val_acc: 0.8348
# Epoch 43/100
# 5000/5000 [==============================] - 1s 152us/sample - loss: 0.6479 - acc: 0.8474
#
# Epoch 00043: val_loss did not improve from 0.61435
#  - 24s - loss: 0.6634 - acc: 0.8368 - val_loss: 0.6473 - val_acc: 0.8474
# Epoch 44/100
# 5000/5000 [==============================] - 1s 159us/sample - loss: 0.6247 - acc: 0.8558
#
# Epoch 00044: val_loss did not improve from 0.61435
#  - 24s - loss: 0.6630 - acc: 0.8362 - val_loss: 0.6239 - val_acc: 0.8558
# Epoch 45/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.5853 - acc: 0.8690
#
# Epoch 00045: val_loss improved from 0.61435 to 0.58471, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.6678 - acc: 0.8345 - val_loss: 0.5847 - val_acc: 0.8690
# Epoch 46/100
# 5000/5000 [==============================] - 1s 152us/sample - loss: 0.6115 - acc: 0.8598
#
# Epoch 00046: val_loss did not improve from 0.58471
#  - 24s - loss: 0.6586 - acc: 0.8373 - val_loss: 0.6128 - val_acc: 0.8598
# Epoch 47/100
# 5000/5000 [==============================] - 1s 153us/sample - loss: 0.6587 - acc: 0.8500
#
# Epoch 00047: val_loss did not improve from 0.58471
#  - 24s - loss: 0.6625 - acc: 0.8376 - val_loss: 0.6585 - val_acc: 0.8500
# Epoch 48/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.6160 - acc: 0.8526
#
# Epoch 00048: val_loss did not improve from 0.58471
#  - 24s - loss: 0.6603 - acc: 0.8380 - val_loss: 0.6152 - val_acc: 0.8526
# Epoch 49/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.7198 - acc: 0.8300
#
# Epoch 00049: val_loss did not improve from 0.58471
#  - 24s - loss: 0.6601 - acc: 0.8392 - val_loss: 0.7191 - val_acc: 0.8300
# Epoch 50/100
# 5000/5000 [==============================] - 1s 152us/sample - loss: 0.6272 - acc: 0.8480
#
# Epoch 00050: val_loss did not improve from 0.58471
#  - 24s - loss: 0.6524 - acc: 0.8396 - val_loss: 0.6262 - val_acc: 0.8480
# Epoch 51/100
# 5000/5000 [==============================] - 1s 152us/sample - loss: 0.6624 - acc: 0.8408
#
# Epoch 00051: val_loss did not improve from 0.58471
#  - 24s - loss: 0.6560 - acc: 0.8398 - val_loss: 0.6621 - val_acc: 0.8408
# Epoch 52/100
# 5000/5000 [==============================] - 1s 151us/sample - loss: 0.6157 - acc: 0.8578
#
# Epoch 00052: val_loss did not improve from 0.58471
#  - 24s - loss: 0.6545 - acc: 0.8382 - val_loss: 0.6154 - val_acc: 0.8578
# Epoch 53/100
# 5000/5000 [==============================] - 1s 151us/sample - loss: 0.6467 - acc: 0.8550
#
# Epoch 00053: val_loss did not improve from 0.58471
#  - 24s - loss: 0.6571 - acc: 0.8385 - val_loss: 0.6472 - val_acc: 0.8550
# Epoch 54/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.5990 - acc: 0.8626
#
# Epoch 00054: val_loss did not improve from 0.58471
#  - 24s - loss: 0.6506 - acc: 0.8402 - val_loss: 0.5981 - val_acc: 0.8626
# Epoch 55/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.5741 - acc: 0.8700
#
# Epoch 00055: val_loss improved from 0.58471 to 0.57425, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.6538 - acc: 0.8405 - val_loss: 0.5743 - val_acc: 0.8700
# Epoch 56/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.6582 - acc: 0.8454
#
# Epoch 00056: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6559 - acc: 0.8413 - val_loss: 0.6572 - val_acc: 0.8454
# Epoch 57/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.5986 - acc: 0.8582
#
# Epoch 00057: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6549 - acc: 0.8409 - val_loss: 0.5981 - val_acc: 0.8582
# Epoch 58/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.6280 - acc: 0.8580
#
# Epoch 00058: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6559 - acc: 0.8407 - val_loss: 0.6286 - val_acc: 0.8580
# Epoch 59/100
# 5000/5000 [==============================] - 1s 152us/sample - loss: 0.6573 - acc: 0.8502
#
# Epoch 00059: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6505 - acc: 0.8420 - val_loss: 0.6578 - val_acc: 0.8502
# Epoch 60/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.6318 - acc: 0.8540
#
# Epoch 00060: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6516 - acc: 0.8404 - val_loss: 0.6330 - val_acc: 0.8540
# Epoch 61/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.6118 - acc: 0.8574
#
# Epoch 00061: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6440 - acc: 0.8442 - val_loss: 0.6118 - val_acc: 0.8574
# Epoch 62/100
# 5000/5000 [==============================] - 1s 159us/sample - loss: 0.6783 - acc: 0.8418
#
# Epoch 00062: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6431 - acc: 0.8440 - val_loss: 0.6809 - val_acc: 0.8418
# Epoch 63/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.6090 - acc: 0.8594
#
# Epoch 00063: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6434 - acc: 0.8430 - val_loss: 0.6082 - val_acc: 0.8594
# Epoch 64/100
# 5000/5000 [==============================] - 1s 157us/sample - loss: 0.5898 - acc: 0.8674
#
# Epoch 00064: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6500 - acc: 0.8416 - val_loss: 0.5893 - val_acc: 0.8674
# Epoch 65/100
# 5000/5000 [==============================] - 1s 151us/sample - loss: 0.6143 - acc: 0.8582
#
# Epoch 00065: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6448 - acc: 0.8440 - val_loss: 0.6164 - val_acc: 0.8582
# Epoch 66/100
# 5000/5000 [==============================] - 1s 157us/sample - loss: 0.6884 - acc: 0.8432
#
# Epoch 00066: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6487 - acc: 0.8424 - val_loss: 0.6884 - val_acc: 0.8432
# Epoch 67/100
# 5000/5000 [==============================] - 1s 155us/sample - loss: 0.6232 - acc: 0.8578
#
# Epoch 00067: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6483 - acc: 0.8421 - val_loss: 0.6230 - val_acc: 0.8578
# Epoch 68/100
# 5000/5000 [==============================] - 1s 155us/sample - loss: 0.6124 - acc: 0.8546
#
# Epoch 00068: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6454 - acc: 0.8431 - val_loss: 0.6112 - val_acc: 0.8546
# Epoch 69/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.6135 - acc: 0.8584
#
# Epoch 00069: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6447 - acc: 0.8429 - val_loss: 0.6135 - val_acc: 0.8584
# Epoch 70/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.5935 - acc: 0.8626
#
# Epoch 00070: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6402 - acc: 0.8445 - val_loss: 0.5931 - val_acc: 0.8626
# Epoch 71/100
# 5000/5000 [==============================] - 1s 155us/sample - loss: 0.5914 - acc: 0.8622
#
# Epoch 00071: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6457 - acc: 0.8437 - val_loss: 0.5923 - val_acc: 0.8622
# Epoch 72/100
# 5000/5000 [==============================] - 1s 155us/sample - loss: 0.5910 - acc: 0.8656
#
# Epoch 00072: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6406 - acc: 0.8459 - val_loss: 0.5900 - val_acc: 0.8656
# Epoch 73/100
# 5000/5000 [==============================] - 1s 157us/sample - loss: 0.5918 - acc: 0.8666
#
# Epoch 00073: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6400 - acc: 0.8449 - val_loss: 0.5912 - val_acc: 0.8666
# Epoch 74/100
# 5000/5000 [==============================] - 1s 158us/sample - loss: 0.6084 - acc: 0.8616
#
# Epoch 00074: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6431 - acc: 0.8459 - val_loss: 0.6088 - val_acc: 0.8616
# Epoch 75/100
# 5000/5000 [==============================] - 1s 153us/sample - loss: 0.6234 - acc: 0.8562
#
# Epoch 00075: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6405 - acc: 0.8444 - val_loss: 0.6222 - val_acc: 0.8562
# Epoch 76/100
# 5000/5000 [==============================] - 1s 157us/sample - loss: 0.6693 - acc: 0.8534
#
# Epoch 00076: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6390 - acc: 0.8459 - val_loss: 0.6683 - val_acc: 0.8534
# Epoch 77/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.6764 - acc: 0.8394
#
# Epoch 00077: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6394 - acc: 0.8463 - val_loss: 0.6752 - val_acc: 0.8394
# Epoch 78/100
# 5000/5000 [==============================] - 1s 155us/sample - loss: 0.6199 - acc: 0.8572
#
# Epoch 00078: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6373 - acc: 0.8467 - val_loss: 0.6197 - val_acc: 0.8572
# Epoch 79/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.6242 - acc: 0.8574
#
# Epoch 00079: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6409 - acc: 0.8458 - val_loss: 0.6249 - val_acc: 0.8574
# Epoch 80/100
# 5000/5000 [==============================] - 1s 155us/sample - loss: 0.6694 - acc: 0.8410
#
# Epoch 00080: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6385 - acc: 0.8472 - val_loss: 0.6697 - val_acc: 0.8410
# Epoch 81/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.6282 - acc: 0.8550
#
# Epoch 00081: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6390 - acc: 0.8462 - val_loss: 0.6280 - val_acc: 0.8550
# Epoch 82/100
# 5000/5000 [==============================] - 1s 157us/sample - loss: 0.5749 - acc: 0.8640
#
# Epoch 00082: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6371 - acc: 0.8481 - val_loss: 0.5744 - val_acc: 0.8640
# Epoch 83/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.6242 - acc: 0.8512
#
# Epoch 00083: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6360 - acc: 0.8470 - val_loss: 0.6238 - val_acc: 0.8512
# Epoch 84/100
# 5000/5000 [==============================] - 1s 161us/sample - loss: 0.6051 - acc: 0.8628
#
# Epoch 00084: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6359 - acc: 0.8485 - val_loss: 0.6036 - val_acc: 0.8628
# Epoch 85/100
# 5000/5000 [==============================] - 1s 156us/sample - loss: 0.6749 - acc: 0.8450
#
# Epoch 00085: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6388 - acc: 0.8479 - val_loss: 0.6750 - val_acc: 0.8450
# Epoch 86/100
# 5000/5000 [==============================] - 1s 152us/sample - loss: 0.5997 - acc: 0.8610
#
# Epoch 00086: val_loss did not improve from 0.57425
#  - 24s - loss: 0.6381 - acc: 0.8470 - val_loss: 0.5986 - val_acc: 0.8610
# Epoch 87/100
# 5000/5000 [==============================] - 1s 159us/sample - loss: 0.5702 - acc: 0.8698
#
# Epoch 00087: val_loss improved from 0.57425 to 0.56939, saving model to aug_model.weights.best.hdf5
#  - 24s - loss: 0.6402 - acc: 0.8458 - val_loss: 0.5694 - val_acc: 0.8698
# Epoch 88/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.6041 - acc: 0.8606
#
# Epoch 00088: val_loss did not improve from 0.56939
#  - 24s - loss: 0.6334 - acc: 0.8484 - val_loss: 0.6036 - val_acc: 0.8606
# Epoch 89/100
# 5000/5000 [==============================] - 1s 158us/sample - loss: 0.6903 - acc: 0.8404
#
# Epoch 00089: val_loss did not improve from 0.56939
#  - 24s - loss: 0.6323 - acc: 0.8504 - val_loss: 0.6898 - val_acc: 0.8404
# Epoch 90/100
# 5000/5000 [==============================] - 1s 162us/sample - loss: 0.6456 - acc: 0.8460
#
# Epoch 00090: val_loss did not improve from 0.56939
#  - 24s - loss: 0.6320 - acc: 0.8500 - val_loss: 0.6448 - val_acc: 0.8460
# Epoch 91/100
# 5000/5000 [==============================] - 1s 158us/sample - loss: 0.5773 - acc: 0.8702
#
# Epoch 00091: val_loss did not improve from 0.56939
#  - 24s - loss: 0.6354 - acc: 0.8483 - val_loss: 0.5763 - val_acc: 0.8702
# Epoch 92/100
# 5000/5000 [==============================] - 1s 157us/sample - loss: 0.6179 - acc: 0.8618
#
# Epoch 00092: val_loss did not improve from 0.56939
#  - 24s - loss: 0.6365 - acc: 0.8464 - val_loss: 0.6165 - val_acc: 0.8618
# Epoch 93/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.5907 - acc: 0.8636
#
# Epoch 00093: val_loss did not improve from 0.56939
#  - 24s - loss: 0.6305 - acc: 0.8487 - val_loss: 0.5893 - val_acc: 0.8636
# Epoch 94/100
# 5000/5000 [==============================] - 1s 157us/sample - loss: 0.6253 - acc: 0.8596
#
# Epoch 00094: val_loss did not improve from 0.56939
#  - 24s - loss: 0.6351 - acc: 0.8472 - val_loss: 0.6256 - val_acc: 0.8596
# Epoch 95/100
# 5000/5000 [==============================] - 1s 152us/sample - loss: 0.5804 - acc: 0.8686
#
# Epoch 00095: val_loss did not improve from 0.56939
#  - 24s - loss: 0.6292 - acc: 0.8496 - val_loss: 0.5800 - val_acc: 0.8686
# Epoch 96/100
# 5000/5000 [==============================] - 1s 154us/sample - loss: 0.6281 - acc: 0.8568
#
# Epoch 00096: val_loss did not improve from 0.56939
#  - 24s - loss: 0.6327 - acc: 0.8478 - val_loss: 0.6279 - val_acc: 0.8568
# Epoch 97/100
# 5000/5000 [==============================] - 1s 155us/sample - loss: 0.5902 - acc: 0.8664
#
# Epoch 00097: val_loss did not improve from 0.56939
#  - 24s - loss: 0.6343 - acc: 0.8493 - val_loss: 0.5893 - val_acc: 0.8664
# Epoch 98/100
# 5000/5000 [==============================] - 1s 151us/sample - loss: 0.6399 - acc: 0.8580
#
# Epoch 00098: val_loss did not improve from 0.56939
#  - 24s - loss: 0.6322 - acc: 0.8488 - val_loss: 0.6393 - val_acc: 0.8580
# Epoch 99/100
# 5000/5000 [==============================] - 1s 157us/sample - loss: 0.7185 - acc: 0.8296
#
# Epoch 00099: val_loss did not improve from 0.56939
#  - 24s - loss: 0.6341 - acc: 0.8506 - val_loss: 0.7191 - val_acc: 0.8296
# Epoch 100/100
# 5000/5000 [==============================] - 1s 155us/sample - loss: 0.5956 - acc: 0.8688
#
# Epoch 00100: val_loss did not improve from 0.56939
#  - 24s - loss: 0.6318 - acc: 0.8488 - val_loss: 0.5955 - val_acc: 0.8688

# %% [markdown]
# ### 10. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# %% [markdown]
# ### 11. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.8569
