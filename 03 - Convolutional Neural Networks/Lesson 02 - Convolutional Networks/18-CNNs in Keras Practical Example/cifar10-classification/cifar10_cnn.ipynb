# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
from tensorflow.keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 24s 0us/step

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from tensorflow.keras.utils import to_categorical

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 11s - loss: 1.6104 - acc: 0.4157 - val_loss: 1.6116 - val_acc: 0.4480
#
# Epoch 00001: val_loss improved from inf to 1.61158, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 6s - loss: 1.2897 - acc: 0.5372 - val_loss: 1.1320 - val_acc: 0.6084
#
# Epoch 00002: val_loss improved from 1.61158 to 1.13205, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 6s - loss: 1.1697 - acc: 0.5818 - val_loss: 1.1942 - val_acc: 0.5850
#
# Epoch 00003: val_loss did not improve from 1.13205
# Epoch 4/100
#  - 6s - loss: 1.1028 - acc: 0.6128 - val_loss: 1.0456 - val_acc: 0.6352
#
# Epoch 00004: val_loss improved from 1.13205 to 1.04555, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 6s - loss: 1.0583 - acc: 0.6306 - val_loss: 0.9636 - val_acc: 0.6676
#
# Epoch 00005: val_loss improved from 1.04555 to 0.96359, saving model to model.weights.best.hdf5
# Epoch 6/100
#  - 6s - loss: 1.0286 - acc: 0.6440 - val_loss: 1.0608 - val_acc: 0.6366
#
# Epoch 00006: val_loss did not improve from 0.96359
# Epoch 7/100
#  - 6s - loss: 1.0136 - acc: 0.6518 - val_loss: 1.0086 - val_acc: 0.6634
#
# Epoch 00007: val_loss did not improve from 0.96359
# Epoch 8/100
#  - 6s - loss: 1.0050 - acc: 0.6561 - val_loss: 1.0805 - val_acc: 0.6284
#
# Epoch 00008: val_loss did not improve from 0.96359
# Epoch 9/100
#  - 6s - loss: 0.9978 - acc: 0.6568 - val_loss: 1.1998 - val_acc: 0.6442
#
# Epoch 00009: val_loss did not improve from 0.96359
# Epoch 10/100
#  - 6s - loss: 0.9983 - acc: 0.6594 - val_loss: 0.8927 - val_acc: 0.7024
#
# Epoch 00010: val_loss improved from 0.96359 to 0.89269, saving model to model.weights.best.hdf5
# Epoch 11/100
#  - 6s - loss: 1.0016 - acc: 0.6604 - val_loss: 1.2572 - val_acc: 0.6154
#
# Epoch 00011: val_loss did not improve from 0.89269
# Epoch 12/100
#  - 6s - loss: 1.0140 - acc: 0.6586 - val_loss: 0.9383 - val_acc: 0.6840
#
# Epoch 00012: val_loss did not improve from 0.89269
# Epoch 13/100
#  - 6s - loss: 1.0340 - acc: 0.6529 - val_loss: 0.9290 - val_acc: 0.6876
#
# Epoch 00013: val_loss did not improve from 0.89269
# Epoch 14/100
#  - 6s - loss: 1.0316 - acc: 0.6541 - val_loss: 1.1242 - val_acc: 0.6794
#
# Epoch 00014: val_loss did not improve from 0.89269
# Epoch 15/100
#  - 6s - loss: 1.0579 - acc: 0.6446 - val_loss: 1.2989 - val_acc: 0.6298
#
# Epoch 00015: val_loss did not improve from 0.89269
# Epoch 16/100
#  - 6s - loss: 1.0708 - acc: 0.6432 - val_loss: 0.9649 - val_acc: 0.6892
#
# Epoch 00016: val_loss did not improve from 0.89269
# Epoch 17/100
#  - 6s - loss: 1.0916 - acc: 0.6390 - val_loss: 1.2058 - val_acc: 0.6584
#
# Epoch 00017: val_loss did not improve from 0.89269
# Epoch 18/100
#  - 6s - loss: 1.1065 - acc: 0.6334 - val_loss: 1.2959 - val_acc: 0.5702
#
# Epoch 00018: val_loss did not improve from 0.89269
# Epoch 19/100
#  - 6s - loss: 1.1298 - acc: 0.6252 - val_loss: 1.1601 - val_acc: 0.6406
#
# Epoch 00019: val_loss did not improve from 0.89269
# Epoch 20/100
#  - 6s - loss: 1.1378 - acc: 0.6221 - val_loss: 1.2187 - val_acc: 0.6072
#
# Epoch 00020: val_loss did not improve from 0.89269
# Epoch 21/100
#  - 6s - loss: 1.1736 - acc: 0.6140 - val_loss: 1.2416 - val_acc: 0.5920
#
# Epoch 00021: val_loss did not improve from 0.89269
# Epoch 22/100
#  - 6s - loss: 1.1889 - acc: 0.6076 - val_loss: 1.3473 - val_acc: 0.6170
#
# Epoch 00022: val_loss did not improve from 0.89269
# Epoch 23/100
#  - 6s - loss: 1.2014 - acc: 0.6003 - val_loss: 1.0075 - val_acc: 0.6724
#
# Epoch 00023: val_loss did not improve from 0.89269
# Epoch 24/100
#  - 6s - loss: 1.2203 - acc: 0.5954 - val_loss: 1.1159 - val_acc: 0.6254
#
# Epoch 00024: val_loss did not improve from 0.89269
# Epoch 25/100
#  - 6s - loss: 1.2471 - acc: 0.5886 - val_loss: 1.0599 - val_acc: 0.6420
#
# Epoch 00025: val_loss did not improve from 0.89269
# Epoch 26/100
#  - 6s - loss: 1.2624 - acc: 0.5861 - val_loss: 1.2092 - val_acc: 0.5820
#
# Epoch 00026: val_loss did not improve from 0.89269
# Epoch 27/100
#  - 6s - loss: 1.2796 - acc: 0.5757 - val_loss: 1.8025 - val_acc: 0.4918
#
# Epoch 00027: val_loss did not improve from 0.89269
# Epoch 28/100
#  - 6s - loss: 1.3158 - acc: 0.5665 - val_loss: 1.1977 - val_acc: 0.6022
#
# Epoch 00028: val_loss did not improve from 0.89269
# Epoch 29/100
#  - 6s - loss: 1.3201 - acc: 0.5634 - val_loss: 1.2478 - val_acc: 0.5700
#
# Epoch 00029: val_loss did not improve from 0.89269
# Epoch 30/100
#  - 6s - loss: 1.3320 - acc: 0.5545 - val_loss: 1.1843 - val_acc: 0.6106
#
# Epoch 00030: val_loss did not improve from 0.89269
# Epoch 31/100
#  - 6s - loss: 1.3334 - acc: 0.5536 - val_loss: 1.5797 - val_acc: 0.5798
#
# Epoch 00031: val_loss did not improve from 0.89269
# Epoch 32/100
#  - 6s - loss: 1.3622 - acc: 0.5474 - val_loss: 1.2852 - val_acc: 0.5628
#
# Epoch 00032: val_loss did not improve from 0.89269
# Epoch 33/100
#  - 6s - loss: 1.3692 - acc: 0.5440 - val_loss: 1.1980 - val_acc: 0.5908
#
# Epoch 00033: val_loss did not improve from 0.89269
# Epoch 34/100
#  - 6s - loss: 1.3752 - acc: 0.5373 - val_loss: 1.3292 - val_acc: 0.5534
#
# Epoch 00034: val_loss did not improve from 0.89269
# Epoch 35/100
#  - 6s - loss: 1.4042 - acc: 0.5308 - val_loss: 1.4129 - val_acc: 0.5018
#
# Epoch 00035: val_loss did not improve from 0.89269
# Epoch 36/100
#  - 6s - loss: 1.4069 - acc: 0.5293 - val_loss: 1.8313 - val_acc: 0.3894
#
# Epoch 00036: val_loss did not improve from 0.89269
# Epoch 37/100
#  - 6s - loss: 1.4119 - acc: 0.5246 - val_loss: 1.5762 - val_acc: 0.5332
#
# Epoch 00037: val_loss did not improve from 0.89269
# Epoch 38/100
#  - 6s - loss: 1.4342 - acc: 0.5205 - val_loss: 1.1857 - val_acc: 0.5910
#
# Epoch 00038: val_loss did not improve from 0.89269
# Epoch 39/100
#  - 6s - loss: 1.4460 - acc: 0.5129 - val_loss: 1.3774 - val_acc: 0.5580
#
# Epoch 00039: val_loss did not improve from 0.89269
# Epoch 40/100
#  - 6s - loss: 1.4453 - acc: 0.5139 - val_loss: 1.3408 - val_acc: 0.5330
#
# Epoch 00040: val_loss did not improve from 0.89269
# Epoch 41/100
#  - 6s - loss: 1.4607 - acc: 0.5073 - val_loss: 1.2698 - val_acc: 0.5612
#
# Epoch 00041: val_loss did not improve from 0.89269
# Epoch 42/100
#  - 6s - loss: 1.4581 - acc: 0.5057 - val_loss: 1.3900 - val_acc: 0.5790
#
# Epoch 00042: val_loss did not improve from 0.89269
# Epoch 43/100
#  - 6s - loss: 1.4827 - acc: 0.4971 - val_loss: 2.7879 - val_acc: 0.4488
#
# Epoch 00043: val_loss did not improve from 0.89269
# Epoch 44/100
#  - 6s - loss: 1.4893 - acc: 0.4971 - val_loss: 1.2598 - val_acc: 0.5748
#
# Epoch 00044: val_loss did not improve from 0.89269
# Epoch 45/100
#  - 6s - loss: 1.5306 - acc: 0.4869 - val_loss: 2.4243 - val_acc: 0.3432
#
# Epoch 00045: val_loss did not improve from 0.89269
# Epoch 46/100
#  - 6s - loss: 1.5465 - acc: 0.4765 - val_loss: 1.4535 - val_acc: 0.4702
#
# Epoch 00046: val_loss did not improve from 0.89269
# Epoch 47/100
#  - 6s - loss: 1.5554 - acc: 0.4690 - val_loss: 1.9744 - val_acc: 0.4714
#
# Epoch 00047: val_loss did not improve from 0.89269
# Epoch 48/100
#  - 6s - loss: 1.5664 - acc: 0.4695 - val_loss: 1.4315 - val_acc: 0.5288
#
# Epoch 00048: val_loss did not improve from 0.89269
# Epoch 49/100
#  - 6s - loss: 1.5649 - acc: 0.4671 - val_loss: 1.4656 - val_acc: 0.4814
#
# Epoch 00049: val_loss did not improve from 0.89269
# Epoch 50/100
#  - 6s - loss: 1.5879 - acc: 0.4610 - val_loss: 1.8844 - val_acc: 0.3982
#
# Epoch 00050: val_loss did not improve from 0.89269
# Epoch 51/100
#  - 6s - loss: 1.6143 - acc: 0.4543 - val_loss: 1.3788 - val_acc: 0.5128
#
# Epoch 00051: val_loss did not improve from 0.89269
# Epoch 52/100
#  - 6s - loss: 1.6303 - acc: 0.4446 - val_loss: 1.5339 - val_acc: 0.4640
#
# Epoch 00052: val_loss did not improve from 0.89269
# Epoch 53/100
#  - 6s - loss: 1.6389 - acc: 0.4360 - val_loss: 1.4204 - val_acc: 0.4924
#
# Epoch 00053: val_loss did not improve from 0.89269
# Epoch 54/100
#  - 6s - loss: 1.6550 - acc: 0.4305 - val_loss: 1.4834 - val_acc: 0.4874
#
# Epoch 00054: val_loss did not improve from 0.89269
# Epoch 55/100
#  - 6s - loss: 1.6708 - acc: 0.4294 - val_loss: 1.5894 - val_acc: 0.4994
#
# Epoch 00055: val_loss did not improve from 0.89269
# Epoch 56/100
#  - 6s - loss: 1.6859 - acc: 0.4199 - val_loss: 2.4761 - val_acc: 0.4070
#
# Epoch 00056: val_loss did not improve from 0.89269
# Epoch 57/100
#  - 6s - loss: 1.6966 - acc: 0.4183 - val_loss: 1.5328 - val_acc: 0.4564
#
# Epoch 00057: val_loss did not improve from 0.89269
# Epoch 58/100
#  - 6s - loss: 1.7007 - acc: 0.4118 - val_loss: 1.5467 - val_acc: 0.4380
#
# Epoch 00058: val_loss did not improve from 0.89269
# Epoch 59/100
#  - 6s - loss: 1.7118 - acc: 0.4095 - val_loss: 1.8425 - val_acc: 0.3194
#
# Epoch 00059: val_loss did not improve from 0.89269
# Epoch 60/100
#  - 6s - loss: 1.7034 - acc: 0.4092 - val_loss: 1.6672 - val_acc: 0.4136
#
# Epoch 00060: val_loss did not improve from 0.89269
# Epoch 61/100
#  - 6s - loss: 1.7169 - acc: 0.4072 - val_loss: 1.4235 - val_acc: 0.4864
#
# Epoch 00061: val_loss did not improve from 0.89269
# Epoch 62/100
#  - 6s - loss: 1.7379 - acc: 0.3981 - val_loss: 1.7431 - val_acc: 0.4016
#
# Epoch 00062: val_loss did not improve from 0.89269
# Epoch 63/100
#  - 6s - loss: 1.7345 - acc: 0.3922 - val_loss: 1.4387 - val_acc: 0.4920
#
# Epoch 00063: val_loss did not improve from 0.89269
# Epoch 64/100
#  - 6s - loss: 1.7437 - acc: 0.3940 - val_loss: 1.7232 - val_acc: 0.3690
#
# Epoch 00064: val_loss did not improve from 0.89269
# Epoch 65/100
#  - 6s - loss: 1.7583 - acc: 0.3895 - val_loss: 2.5242 - val_acc: 0.3398
#
# Epoch 00065: val_loss did not improve from 0.89269
# Epoch 66/100
#  - 6s - loss: 1.7471 - acc: 0.3876 - val_loss: 1.4098 - val_acc: 0.4960
#
# Epoch 00066: val_loss did not improve from 0.89269
# Epoch 67/100
#  - 6s - loss: 1.7631 - acc: 0.3855 - val_loss: 1.5125 - val_acc: 0.4752
#
# Epoch 00067: val_loss did not improve from 0.89269
# Epoch 68/100
#  - 6s - loss: 1.7581 - acc: 0.3841 - val_loss: 2.2603 - val_acc: 0.2280
#
# Epoch 00068: val_loss did not improve from 0.89269
# Epoch 69/100
#  - 6s - loss: 1.7572 - acc: 0.3856 - val_loss: 2.5175 - val_acc: 0.3522
#
# Epoch 00069: val_loss did not improve from 0.89269
# Epoch 70/100
#  - 6s - loss: 1.7587 - acc: 0.3766 - val_loss: 1.9451 - val_acc: 0.3234
#
# Epoch 00070: val_loss did not improve from 0.89269
# Epoch 71/100
#  - 6s - loss: 1.7558 - acc: 0.3809 - val_loss: 1.5752 - val_acc: 0.4304
#
# Epoch 00071: val_loss did not improve from 0.89269
# Epoch 72/100
#  - 6s - loss: 1.7583 - acc: 0.3798 - val_loss: 1.4639 - val_acc: 0.4702
#
# Epoch 00072: val_loss did not improve from 0.89269
# Epoch 73/100
#  - 6s - loss: 1.7651 - acc: 0.3726 - val_loss: 2.6430 - val_acc: 0.3754
#
# Epoch 00073: val_loss did not improve from 0.89269
# Epoch 74/100
#  - 6s - loss: 1.7585 - acc: 0.3759 - val_loss: 1.6841 - val_acc: 0.4476
#
# Epoch 00074: val_loss did not improve from 0.89269
# Epoch 75/100
#  - 6s - loss: 1.7831 - acc: 0.3711 - val_loss: 1.6323 - val_acc: 0.3850
#
# Epoch 00075: val_loss did not improve from 0.89269
# Epoch 76/100
#  - 6s - loss: 1.7790 - acc: 0.3694 - val_loss: 1.8259 - val_acc: 0.3684
#
# Epoch 00076: val_loss did not improve from 0.89269
# Epoch 77/100
#  - 6s - loss: 1.7901 - acc: 0.3653 - val_loss: 1.6178 - val_acc: 0.4034
#
# Epoch 00077: val_loss did not improve from 0.89269
# Epoch 78/100
#  - 6s - loss: 1.7927 - acc: 0.3641 - val_loss: 1.5691 - val_acc: 0.4270
#
# Epoch 00078: val_loss did not improve from 0.89269
# Epoch 79/100
#  - 6s - loss: 1.7899 - acc: 0.3620 - val_loss: 1.5999 - val_acc: 0.4144
#
# Epoch 00079: val_loss did not improve from 0.89269
# Epoch 80/100
#  - 6s - loss: 1.7997 - acc: 0.3639 - val_loss: 1.5471 - val_acc: 0.4208
#
# Epoch 00080: val_loss did not improve from 0.89269
# Epoch 81/100
#  - 6s - loss: 1.7893 - acc: 0.3626 - val_loss: 1.6398 - val_acc: 0.3934
#
# Epoch 00081: val_loss did not improve from 0.89269
# Epoch 82/100
#  - 6s - loss: 1.7855 - acc: 0.3632 - val_loss: 1.6095 - val_acc: 0.4280
#
# Epoch 00082: val_loss did not improve from 0.89269
# Epoch 83/100
#  - 6s - loss: 1.7854 - acc: 0.3608 - val_loss: 1.8017 - val_acc: 0.3892
#
# Epoch 00083: val_loss did not improve from 0.89269
# Epoch 84/100
#  - 6s - loss: 1.7864 - acc: 0.3559 - val_loss: 1.9887 - val_acc: 0.2836
#
# Epoch 00084: val_loss did not improve from 0.89269
# Epoch 85/100
#  - 6s - loss: 1.8034 - acc: 0.3596 - val_loss: 1.7128 - val_acc: 0.4026
#
# Epoch 00085: val_loss did not improve from 0.89269
# Epoch 86/100
#  - 6s - loss: 1.8231 - acc: 0.3428 - val_loss: 2.0092 - val_acc: 0.3038
#
# Epoch 00086: val_loss did not improve from 0.89269
# Epoch 87/100
#  - 6s - loss: 1.8239 - acc: 0.3496 - val_loss: 1.6927 - val_acc: 0.3828
#
# Epoch 00087: val_loss did not improve from 0.89269
# Epoch 88/100
#  - 6s - loss: 1.8207 - acc: 0.3494 - val_loss: 2.0857 - val_acc: 0.2748
#
# Epoch 00088: val_loss did not improve from 0.89269
# Epoch 89/100
#  - 6s - loss: 1.8203 - acc: 0.3484 - val_loss: 1.6408 - val_acc: 0.3952
#
# Epoch 00089: val_loss did not improve from 0.89269
# Epoch 90/100
#  - 6s - loss: 1.8289 - acc: 0.3468 - val_loss: 1.6098 - val_acc: 0.4282
#
# Epoch 00090: val_loss did not improve from 0.89269
# Epoch 91/100
#  - 6s - loss: 1.8184 - acc: 0.3475 - val_loss: 1.9359 - val_acc: 0.3788
#
# Epoch 00091: val_loss did not improve from 0.89269
# Epoch 92/100
#  - 6s - loss: 1.8274 - acc: 0.3484 - val_loss: 1.9911 - val_acc: 0.2330
#
# Epoch 00092: val_loss did not improve from 0.89269
# Epoch 93/100
#  - 6s - loss: 1.8292 - acc: 0.3486 - val_loss: 1.8876 - val_acc: 0.2932
#
# Epoch 00093: val_loss did not improve from 0.89269
# Epoch 94/100
#  - 6s - loss: 1.8335 - acc: 0.3441 - val_loss: 1.7797 - val_acc: 0.3534
#
# Epoch 00094: val_loss did not improve from 0.89269
# Epoch 95/100
#  - 6s - loss: 1.8374 - acc: 0.3398 - val_loss: 1.7574 - val_acc: 0.3686
#
# Epoch 00095: val_loss did not improve from 0.89269
# Epoch 96/100
#  - 6s - loss: 1.8436 - acc: 0.3405 - val_loss: 1.6270 - val_acc: 0.4016
#
# Epoch 00096: val_loss did not improve from 0.89269
# Epoch 97/100
#  - 6s - loss: 1.8496 - acc: 0.3401 - val_loss: 1.7491 - val_acc: 0.3686
#
# Epoch 00097: val_loss did not improve from 0.89269
# Epoch 98/100
#  - 6s - loss: 1.8524 - acc: 0.3384 - val_loss: 1.6114 - val_acc: 0.4132
#
# Epoch 00098: val_loss did not improve from 0.89269
# Epoch 99/100
#  - 6s - loss: 1.8495 - acc: 0.3363 - val_loss: 1.6960 - val_acc: 0.3688
#
# Epoch 00099: val_loss did not improve from 0.89269
# Epoch 100/100
#  - 6s - loss: 1.8458 - acc: 0.3375 - val_loss: 1.7684 - val_acc: 0.3842
#
# Epoch 00100: val_loss did not improve from 0.89269

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6938

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
